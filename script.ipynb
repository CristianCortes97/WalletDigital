-- %% [markdown]
-- # [WALLETDIGITALDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [WALLETDIGITALDB]    Script Date: 24/04/2025 12:13:07 p. m. ******/
IF NOT EXISTS (SELECT name FROM sys.databases WHERE name = N'WALLETDIGITALDB')
BEGIN
CREATE DATABASE [WALLETDIGITALDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'WALLET', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\WALLET.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'WALLET_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\WALLET_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
END
GO
ALTER DATABASE [WALLETDIGITALDB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [WALLETDIGITALDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [WALLETDIGITALDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [WALLETDIGITALDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [WALLETDIGITALDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [WALLETDIGITALDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [WALLETDIGITALDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET RECOVERY FULL 
GO
ALTER DATABASE [WALLETDIGITALDB] SET  MULTI_USER 
GO
ALTER DATABASE [WALLETDIGITALDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [WALLETDIGITALDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [WALLETDIGITALDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [WALLETDIGITALDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [WALLETDIGITALDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [WALLETDIGITALDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'WALLETDIGITALDB', N'ON'
GO
ALTER DATABASE [WALLETDIGITALDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [WALLETDIGITALDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[TRANSACTIONS]

-- %%
USE [WALLETDIGITALDB]
GO

-- %%
/****** Object:  Table [dbo].[TRANSACTIONS]    Script Date: 24/04/2025 12:13:07 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
IF NOT EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[TRANSACTIONS]') AND type in (N'U'))
BEGIN
CREATE TABLE [dbo].[TRANSACTIONS](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[wallet_id] [int] NOT NULL,
	[amount] [decimal](18, 2) NOT NULL,
	[type] [bit] NOT NULL,
	[create_at] [datetime] NOT NULL,
 CONSTRAINT [PK_TRANSACTIONS] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
END
GO

-- %% [markdown]
-- # [dbo].[WALLET]

-- %%
/****** Object:  Table [dbo].[WALLET]    Script Date: 24/04/2025 12:13:07 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
IF NOT EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[WALLET]') AND type in (N'U'))
BEGIN
CREATE TABLE [dbo].[WALLET](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[document_id] [varchar](50) NOT NULL,
	[name] [varchar](100) NOT NULL,
	[balance] [decimal](18, 2) NOT NULL,
	[create_at] [datetime] NOT NULL,
	[update_at] [datetime] NOT NULL,
 CONSTRAINT [PK_WALLET] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
END
GO

-- %% [markdown]
-- # [FK_TRANSACTIONS_WALLET]

-- %%
IF NOT EXISTS (SELECT * FROM sys.foreign_keys WHERE object_id = OBJECT_ID(N'[dbo].[FK_TRANSACTIONS_WALLET]') AND parent_object_id = OBJECT_ID(N'[dbo].[TRANSACTIONS]'))
ALTER TABLE [dbo].[TRANSACTIONS]  WITH CHECK ADD  CONSTRAINT [FK_TRANSACTIONS_WALLET] FOREIGN KEY([wallet_id])
REFERENCES [dbo].[WALLET] ([id])
GO
IF  EXISTS (SELECT * FROM sys.foreign_keys WHERE object_id = OBJECT_ID(N'[dbo].[FK_TRANSACTIONS_WALLET]') AND parent_object_id = OBJECT_ID(N'[dbo].[TRANSACTIONS]'))
ALTER TABLE [dbo].[TRANSACTIONS] CHECK CONSTRAINT [FK_TRANSACTIONS_WALLET]
GO

-- %% [markdown]
-- # [WALLETDIGITALDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [WALLETDIGITALDB] SET  READ_WRITE 
GO
